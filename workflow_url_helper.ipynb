# %%
import requests
from bs4 import BeautifulSoup

base_url = "https://download.geofabrik.de/north-america/"
country = "us"
response = requests.get(base_url + country + ".html")
soup = BeautifulSoup(response.text, 'html.parser')
table = soup.find_all('table', id="subregions")[1]
rows = table.find_all('tr')

# %%
state_cnt = 1
for row in rows:
    for entry in row.find_all('a', href=True):
        link = entry['href']
        if "latest.osm.pbf" in link:
            name = link.split('/')[-1].replace('-latest.osm.pbf', '')
            print("{ name:", name,", url: ",base_url + link, ", state: \"" + str(state_cnt).rjust(2, '0') + "00\"},")
            state_cnt += 1
# Out:
# { name: alabama , url:  https://download.geofabrik.de/north-america/us/alabama-latest.osm.pbf , state: "0100"},
# { name: alaska , url:  https://download.geofabrik.de/north-america/us/alaska-latest.osm.pbf , state: "0200"},
# { name: arizona , url:  https://download.geofabrik.de/north-america/us/arizona-latest.osm.pbf , state: "0300"},
# { name: arkansas , url:  https://download.geofabrik.de/north-america/us/arkansas-latest.osm.pbf , state: "0400"},
# { name: california , url:  https://download.geofabrik.de/north-america/us/california-latest.osm.pbf , state: "0500"},
# { name: colorado , url:  https://download.geofabrik.de/north-america/us/colorado-latest.osm.pbf , state: "0600"},
# { name: connecticut , url:  https://download.geofabrik.de/north-america/us/connecticut-latest.osm.pbf , state: "0700"},
# { name: delaware , url:  https://download.geofabrik.de/north-america/us/delaware-latest.osm.pbf , state: "0800"},
# { name: district-of-columbia , url:  https://download.geofabrik.de/north-america/us/district-of-columbia-latest.osm.pbf , state: "0900"},
# { name: florida , url:  https://download.geofabrik.de/north-america/us/florida-latest.osm.pbf , state: "1000"},
# { name: georgia , url:  https://download.geofabrik.de/north-america/us/georgia-latest.osm.pbf , state: "1100"},
# { name: hawaii , url:  https://download.geofabrik.de/north-america/us/hawaii-latest.osm.pbf , state: "1200"},
# { name: idaho , url:  https://download.geofabrik.de/north-america/us/idaho-latest.osm.pbf , state: "1300"},
# { name: illinois , url:  https://download.geofabrik.de/north-america/us/illinois-latest.osm.pbf , state: "1400"},
# { name: indiana , url:  https://download.geofabrik.de/north-america/us/indiana-latest.osm.pbf , state: "1500"},
# { name: iowa , url:  https://download.geofabrik.de/north-america/us/iowa-latest.osm.pbf , state: "1600"},
# { name: kansas , url:  https://download.geofabrik.de/north-america/us/kansas-latest.osm.pbf , state: "1700"},
# { name: kentucky , url:  https://download.geofabrik.de/north-america/us/kentucky-latest.osm.pbf , state: "1800"},
# { name: louisiana , url:  https://download.geofabrik.de/north-america/us/louisiana-latest.osm.pbf , state: "1900"},
# { name: maine , url:  https://download.geofabrik.de/north-america/us/maine-latest.osm.pbf , state: "2000"},
# { name: maryland , url:  https://download.geofabrik.de/north-america/us/maryland-latest.osm.pbf , state: "2100"},
# { name: massachusetts , url:  https://download.geofabrik.de/north-america/us/massachusetts-latest.osm.pbf , state: "2200"},
# { name: michigan , url:  https://download.geofabrik.de/north-america/us/michigan-latest.osm.pbf , state: "2300"},
# { name: minnesota , url:  https://download.geofabrik.de/north-america/us/minnesota-latest.osm.pbf , state: "2400"},
# { name: mississippi , url:  https://download.geofabrik.de/north-america/us/mississippi-latest.osm.pbf , state: "2500"},
# { name: missouri , url:  https://download.geofabrik.de/north-america/us/missouri-latest.osm.pbf , state: "2600"},
# { name: montana , url:  https://download.geofabrik.de/north-america/us/montana-latest.osm.pbf , state: "2700"},
# { name: nebraska , url:  https://download.geofabrik.de/north-america/us/nebraska-latest.osm.pbf , state: "2800"},
# { name: nevada , url:  https://download.geofabrik.de/north-america/us/nevada-latest.osm.pbf , state: "2900"},
# { name: new-hampshire , url:  https://download.geofabrik.de/north-america/us/new-hampshire-latest.osm.pbf , state: "3000"},
# { name: new-jersey , url:  https://download.geofabrik.de/north-america/us/new-jersey-latest.osm.pbf , state: "3100"},
# { name: new-mexico , url:  https://download.geofabrik.de/north-america/us/new-mexico-latest.osm.pbf , state: "3200"},
# { name: new-york , url:  https://download.geofabrik.de/north-america/us/new-york-latest.osm.pbf , state: "3300"},
# { name: north-carolina , url:  https://download.geofabrik.de/north-america/us/north-carolina-latest.osm.pbf , state: "3400"},
# { name: north-dakota , url:  https://download.geofabrik.de/north-america/us/north-dakota-latest.osm.pbf , state: "3500"},
# { name: ohio , url:  https://download.geofabrik.de/north-america/us/ohio-latest.osm.pbf , state: "3600"},
# { name: oklahoma , url:  https://download.geofabrik.de/north-america/us/oklahoma-latest.osm.pbf , state: "3700"},
# { name: oregon , url:  https://download.geofabrik.de/north-america/us/oregon-latest.osm.pbf , state: "3800"},
# { name: pennsylvania , url:  https://download.geofabrik.de/north-america/us/pennsylvania-latest.osm.pbf , state: "3900"},
# { name: puerto-rico , url:  https://download.geofabrik.de/north-america/us/puerto-rico-latest.osm.pbf , state: "4000"},
# { name: rhode-island , url:  https://download.geofabrik.de/north-america/us/rhode-island-latest.osm.pbf , state: "4100"},
# { name: south-carolina , url:  https://download.geofabrik.de/north-america/us/south-carolina-latest.osm.pbf , state: "4200"},
# { name: south-dakota , url:  https://download.geofabrik.de/north-america/us/south-dakota-latest.osm.pbf , state: "4300"},
# { name: tennessee , url:  https://download.geofabrik.de/north-america/us/tennessee-latest.osm.pbf , state: "4400"},
# { name: texas , url:  https://download.geofabrik.de/north-america/us/texas-latest.osm.pbf , state: "4500"},
# { name: us-virgin-islands , url:  https://download.geofabrik.de/north-america/us/us-virgin-islands-latest.osm.pbf , state: "4600"},
# { name: utah , url:  https://download.geofabrik.de/north-america/us/utah-latest.osm.pbf , state: "4700"},
# { name: vermont , url:  https://download.geofabrik.de/north-america/us/vermont-latest.osm.pbf , state: "4800"},
# { name: virginia , url:  https://download.geofabrik.de/north-america/us/virginia-latest.osm.pbf , state: "4900"},
# { name: washington , url:  https://download.geofabrik.de/north-america/us/washington-latest.osm.pbf , state: "5000"},
# { name: west-virginia , url:  https://download.geofabrik.de/north-america/us/west-virginia-latest.osm.pbf , state: "5100"},
# { name: wisconsin , url:  https://download.geofabrik.de/north-america/us/wisconsin-latest.osm.pbf , state: "5200"},
# { name: wyoming , url:  https://download.geofabrik.de/north-america/us/wyoming-latest.osm.pbf , state: "5300"},

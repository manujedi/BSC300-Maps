# %%
import ctypes
from pathlib import Path
import pandas as pd
import plotly.graph_objects as go
import plotly.express as px
import numpy as np
import math
import pprint
from datetime import datetime

# %%
class MapsForgeHeader:
    magic_byte: str
    header_size: int
    file_version: int
    file_size: int
    date_of_creation: datetime
    minLat: int
    minLon: int
    maxLat: int
    maxLon: int
    tile_size: int
    projection: str
    flags: int
    mapStartLat: int
    mapStartLon: int
    start_zoom_level: int
    language:str
    comment:str
    created_by:str
    poiTags:list
    wayTags:list
    zoom_interval_configs:list


class ParsedFileName:
    country: str
    state: str
    creationDate: str
    minLong: int
    minLat: int
    sizeNorthSouth: int
    sizeWestEast: int

    def __init__(self, filename):
        self.country = filename[:2]
        self.state = filename[2:6]
        self.creationDate = filename[6:12]
        self.field1 = int(filename[12:15], 36)
        self.field2 = int(filename[15:18], 36)
        self.z1 = int(filename[18:21], 36)
        self.z2 = int(filename[21:24], 36)


def parseVBEU(data: bytes):
    idx = 0
    value = 0
    while data[idx] & 0x80:
        value += (data[idx] & 0x7F) << (7 * idx)
        idx += 1
    value += (data[idx] & 0x7F) << (7 * idx)
    idx += 1

    return value, idx


def parseVBES(data: bytes):
    idx = 0
    value = 0
    while data[idx] & 0x80:
        value += (data[idx] & 0x7F) << (7 * idx)
        idx += 1
    value += (data[idx] & 0x3F) << (7 * idx)
    value *= -1 if data[idx] & 0x40 else 1
    idx += 1

    return value, idx


def parseHeader(file: Path) -> MapsForgeHeader:
    data = open(file, "rb").read(2000)
    header = MapsForgeHeader()
    idx = 0
    header.magic_byte = data[idx : idx + 20]
    idx += 20
    header.header_size = int.from_bytes(data[idx : idx + 4])
    idx += 4


    assert header.header_size < 1900, "didn't read enough bytes"

    header.file_version = int.from_bytes(data[idx : idx + 4])
    idx += 4
    header.file_size = int.from_bytes(data[idx : idx + 8])
    idx += 8
    header.date_of_creation = datetime.fromtimestamp(
        int.from_bytes(data[idx : idx + 8]) / 1000
    )
    idx += 8
    header.minLat = int.from_bytes(data[idx : idx + 4], signed=True) / 10**6
    idx += 4
    header.minLon = int.from_bytes(data[idx : idx + 4], signed=True) / 10**6
    idx += 4
    header.maxLat = int.from_bytes(data[idx : idx + 4], signed=True) / 10**6
    idx += 4
    header.maxLon = int.from_bytes(data[idx : idx + 4], signed=True) / 10**6
    idx += 4
    header.tile_size = int.from_bytes(data[idx : idx + 2])
    idx += 2

    strlen, used_bytes = parseVBEU(data[idx:])
    idx += used_bytes
    header.projection = data[idx : idx + strlen]
    idx += strlen

    flags = data[idx]
    header.flags = flags
    idx += 1

    if flags & 0x40:
        header.mapStartLat = int.from_bytes(data[idx : idx + 4], signed=True) / 10**6
        idx += 4
        header.mapStartLon = int.from_bytes(data[idx : idx + 4], signed=True) / 10**6
        idx += 4

    if flags & 0x20:
        header.start_zoom_level = int.from_bytes(data[idx : idx + 1])
        idx += 1

    if flags & 0x10:
        strlen, used_bytes = parseVBEU(data[idx:])
        idx += used_bytes
        header.language = data[idx : idx + strlen]
        idx += strlen

    if flags & 0x08:
        strlen, used_bytes = parseVBEU(data[idx:])
        idx += used_bytes
        header.comment = data[idx : idx + strlen]
        idx += strlen

    if flags & 0x04:
        strlen, used_bytes = parseVBEU(data[idx:])
        idx += used_bytes
        header.created_by = data[idx : idx + strlen]
        idx += strlen

    if flags & 0x03:
        print("parse error, future usage fileds")

    poiTagsCnt = int.from_bytes(data[idx : idx + 2])
    idx += 2
    header.poiTags = []
    for i in range(poiTagsCnt):
        strlen, used_bytes = parseVBEU(data[idx:])
        idx += used_bytes
        tag = data[idx : idx + strlen]
        idx += strlen
        header.poiTags.append(tag)
    header.poiTags.sort()

    wayTagsCnt = int.from_bytes(data[idx : idx + 2])
    idx += 2
    header.wayTags = []
    for i in range(wayTagsCnt):
        strlen, used_bytes = parseVBEU(data[idx:])
        idx += used_bytes
        tag = data[idx : idx + strlen]
        idx += strlen
        header.wayTags.append(tag)
    header.wayTags.sort()

    amount_zoom_intervals = int.from_bytes(data[idx:idx+1])
    idx += 1

    header.zoom_interval_configs = []
    for i in range(amount_zoom_intervals):
        basezoom = int.from_bytes(data[idx : idx + 1])
        idx += 1
        minzoom = int.from_bytes(data[idx : idx + 1])
        idx += 1
        maxzoom = int.from_bytes(data[idx : idx + 1])
        idx += 1
        absstart = int.from_bytes(data[idx : idx + 8])
        idx += 8
        sizesub = int.from_bytes(data[idx : idx + 8])
        idx += 8
        header.zoom_interval_configs.append({
            "basezoom": basezoom,
            "minzoom": minzoom,
            "maxzoom": maxzoom,
            "absstart": absstart,
            "sizesub": sizesub,
        })

    # assert(idx - 24 == header.header_size)

    return header


def parseFilename(filename) -> ParsedFileName:
    return ParsedFileName(filename)

# %%
files = [f for f in Path("./").glob("*.map") if f.is_file()]
files = [f for f in Path("./my_maps").rglob("*.map") if f.is_file()]
files = [f for f in Path("./factory_data/00D6-5BD8/iGPSPORT/").rglob("*.map") if f.is_file()]

files =  sorted(files, key=lambda x: x.name)
data = []


print("--- files ----   (", len(files), ")")

for i in files:
    print(i)
# Out:
# --- files ----   ( 432 )
# factory_data/00D6-5BD8/iGPSPORT/Maps/AR010023031021O3S204B068.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/AR020023031024S3T1004006.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/AR03002303101Y33M702R03K.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/AR040023031021O3LG03702U.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/AR05002303101W43Z205N03K.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/AR06002303102063PA02K046.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/AR07002303102413NO02L02J.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/AR080023031023C3PR01X02Y.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/AR090023031022C3KC032033.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/AR10002303101ZA3JV01Y01Z.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/AR11002303101YL3TE03503H.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/AR12002303101XQ3O102Q034.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/AR13002303101X53R402M04C.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/AR140023031026B3MF01K01X.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/AR15002303101W93U702K045.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/AR16002303101WB3VF05S03O.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/AR17002303101YF3K003Y033.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/AR18002303101X53OH02I035.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/AR19002303101Z43R001N037.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/AR20002303101V942K04Z069.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/AR21002303102203O702K04R.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/AR220023031020K3MJ02803I.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/AR23002303101YE49103202M.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/AR24002303101ZX3MU01401F.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/AU01002303105RT3TI00E00N.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/AU02002303105MV3O80BR079.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/AU03002303105FA3CK05R0AA.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/AU04002303105KZ3BL0BA0DI.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/AU05002303105FA3MS07N099.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/AU06002303105OH3WP0A10FA.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/AU07002303105MV3SM05V045.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/AU080023031054Z3EC0AD0FF.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/BE010023031038G249006006.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/BE020023031037D23N02500V.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/BE030023031037K24C02501C.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/BE040023031039J24F00A00M.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/BR01002303102B83FO00N00E.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/BR02002303102833DN04O04Q.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/BR030023031022S3AE07A070.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/BR040023031024Z3GS04M04P.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/BR05002303101UZ3A904P02M.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/BR060023031027232T03J03R.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/BR07002303101V334C0B907P.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/BR080023031024I34408907X.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/BR09002303101ZJ3AT04H03P.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/BR100023031020S32F03S04D.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/BR110023031029O39103805C.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/BR12002303102HL3BC023018.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/BR13002303102CA3B506006H.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/BR14002303102FK37E02S03D.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/BR15002303102AY36804H063.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/BR16002303102H939K02O01I.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/BR17002303102FL35107S06S.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/BR18002303102CO37E03L05C.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/BR19002303102HD382036025.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/BR20002303102HL3BT01901C.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/BR21002303102783KD04B02Y.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/BR220023031025B3NK056050.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/BR230023031027Q3MR03N02I.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/BR24002303102FA3H808F02H.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/BR250023031029H3EU07405V.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/BR26002303102DE3J602O021.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/BR27002303102863II05P03Y.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CH01002303103AN27G00H00G.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CH02002303103BL27L00A008.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CH03002303103BN27M007007.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CH04002303103AE27I00F008.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CH05002303103AJ27H004003.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CH06002303103A327P01100Z.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CH07002303103A128000F00K.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CH080023031039J28M008008.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CH09002303103BD27V00900D.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CH10002303103B827Y01700V.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CH11002303103A327K00H00C.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CH12002303103AQ27R00F00H.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CH130023031039U27V00F00B.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CH14002303103AY280009009.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CH15002303103AU28100B008.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CH16002303103BC27I00K00N.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CH17002303103B327A00B008.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CH18002303103B227T00F00C.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CH19002303103AE27K00G00E.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CH20002303103B927D00J00B.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CH21002303103B228D00I00R.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CH22002303103B228100D00G.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CH23002303103A128C01400R.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CH240023031039L28100S00R.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CH25002303103B227S008006.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CH26002303103B227D00E00J.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CL00002303101673GZ0U60YL.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CN010023031056D2ID03203Z.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CN020023031056P2D801D01E.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CN030023031050B2K8034030.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CN040023031056Z2N303B03L.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CN05002303104S32BR0AF088.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CN060023031052Y2P205703Q.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CN07002303104ZT2OG04T03Y.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CN08002303104Z92MF03S03B.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CN09002303105292SM06604A.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CN100023031055H2BX04T05F.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CN11002303105AC21H08N09T.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CN120023031053I2H204003T.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CN130023031055P2R400G00B.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CN14002303105292JF04Y036.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CN150023031052J2LR03H03Y.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CN16002303104V621Q0IB0EK.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CN170023031057B2I003U03C.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CN180023031055J2LT035040.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CN19002303105AN28N06504T.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CN200023031058V2B604F049.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CN210023031055J2RD002003.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CN22002303104ZO2EM02603C.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CN23002303104Q92EQ08P062.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CN240023031050G2EH03N065.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CN250023031056C2FC05603A.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CN26002303105A52KH01M00X.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CN270023031053F2DI02S04Z.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CN28002303104VA2IM074064.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CN290023031057J2DX00W01F.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CN30002303104JB2GX0D506X.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CN31002303104G725X0EJ0CR.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CN32002303104VE2ME05I05P.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CN330023031058D2KZ03A036.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CO00002303101P62V90AD0D7.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CR00002303101ML2YM03203S.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CZ01002303103EB25I01C013.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CZ02002303103FL25I01C011.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CZ03002303103DE24P00T00L.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CZ04002303103FB24D00Y00S.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CZ05002303103ET24400V00M.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CZ06002303103GL24T01400Z.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CZ07002303103GB24P00T017.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CZ08002303103FH24Y00Z00O.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CZ09002303103DL25100Y017.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CZ10002303103ER24Z00B009.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CZ11002303103E824J01D015.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CZ12002303103DY243013011.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CZ13002303103F625A01000Y.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/CZ14002303103GK25L00V00Q.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/DE01002303103AI25D01X026.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/DE02002303103BG24M033036.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/DE03002303103E122G00G00D.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/DE04002303103CV21I02902B.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/DE05002303103B421H00C00N.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/DE06002303103BU21C00H00D.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/DE07002303103AO23I01L029.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/DE08002303103CG1ZZ02G021.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/DE090023031039R20Z03D02W.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/DE100023031039H22L02A029.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/DE110023031039N24801I01Y.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/DE120023031039S25I00O00J.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/DE13002303103DA23H02001J.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/DE14002303103CG22201O027.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/DE15002303103AH1ZT02U01Y.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/DE16002303103C023I01S01H.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/DK00002303103AN1WG051045.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/EC00002303101IM33Z0BN04Z.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/ES01002303103102F603R029.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/ES020023031034E2BN01V02N.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/ES03002303103182B001P00Q.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/ES04002303102UA2MA03301B.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/ES050023031032P2B501300P.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/ES060023031032C2D002V02R.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/ES070023031031A2BE03E02P.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/ES080023031035V2BP021021.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/ES090023031032C2HF003001.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/ES100023031032V2D500Z014.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/ES11002303103462BB015019.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/ES120023031034S2DH01G02F.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/ES130023031033L2B701400W.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/ES140023031030Z2DQ01V024.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/ES15002303102ZV2AW01O01R.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/ES160023031036H2E1021018.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/ES170023031033S2BW00Y00O.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/ES18002303103312HV018005.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/ES190023031034A2F5013015.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/FR01002303103A326100W01M.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/FR020023031034M29702302M.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/FR030023031037228701K020.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/FR040023031034J25F01V01J.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/FR050023031037K26P01Q024.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/FR060023031032I26702N01L.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/FR070023031035S26601Z02H.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/FR080023031037W24Z01M02J.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/FR09002303103B52BK00O01H.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/FR100023031039327201801O.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/FR110023031035T25201401F.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/FR120023031036O25W01D014.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/FR130023031036U29V02002C.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/FR140023031036528I01A01G.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/FR150023031038U25J01S01R.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/FR160023031035K29S02E027.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/FR170023031036Q24201Q016.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/FR180023031034326J02A027.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/FR190023031036M24S01V01J.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/FR200023031034S27U01S01Y.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/FR210023031038F29Q02901X.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/FR220023031038328G028027.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/HU00002303103FY26J04B02O.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/ID01002303104TO31S02I033.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/ID02002303105633AH00X012.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/ID030023031050435Y02Y030.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/ID04002303104ZW39801E01A.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/ID05002303104X6377028027.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/ID060023031052F38C02302T.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/ID070023031053Q35903A03T.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/ID080023031058W34R03V036.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/ID090023031053U38V03L02N.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/ID100023031055P34403Q03C.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/ID110023031058L3A104K02W.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/ID12002303105AC34W01J00X.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/ID130023031050Y38X00G00W.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/ID14002303104XO36302I01G.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/ID15002303104Z638402501R.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/ID16002303105CQ37606K042.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/ID170023031056632Z02P025.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/ID18002303105C333L03Q03Z.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/ID19002303105BL32402Z041.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/ID20002303104UW32Y02J03I.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/ID21002303105I535104S06Q.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/ID22002303104X033T02I02O.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/ID23002303104YW32L04903Y.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/ID240023031055T36L02I02O.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/ID250023031057C36Y03S03V.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/ID26002303104YA36Q02W027.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/ID27002303105A037H03602P.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/ID280023031050S38B01Y02K.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/ID290023031052234A03X04H.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/ID300023031056T3A102I01O.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/ID31002303105EY34Y04C03W.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/ID320023031058435W01H02E.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/ID33002303104VU35702C02V.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/ID34002303105383AJ00M00L.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/IT01002303103DZ2BO015013.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/IT02002303103FG2D6010013.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/IT03002303103FN2E001001U.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/IT04002303103EG2CV01C01B.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/IT05002303103BK29P02A01A.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/IT06002303103DJ28C012010.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/IT07002303103D02BQ01N01S.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/IT08002303103AI2A401N00U.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/IT09002303103B428C01W01T.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/IT10002303103DG2AR015015.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/IT11002303103EK2CE00T00M.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/IT120023031039Y28I01O027.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/IT13002303103F72C902A023.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/IT14002303103AW2D1014022.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/IT15002303103DA2F302E02O.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/IT16002303103BW2AB01P01Z.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/IT17002303103CB27X01D01C.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/IT18002303103DA2B200W014.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/IT19002303103A228Y00R00I.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/IT20002303103CH28B01L01R.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/JP01002303105K52HS00S00X.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/JP02002303105LU2DQ01201C.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/JP03002303105LS2CT01P015.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/JP04002303105LY2H9011016.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/JP05002303105H52IN015016.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/JP06002303105JE2H000V00V.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/JP07002303105FT2IE00X01B.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/JP08002303105LQ2FS01G00Z.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/JP09002303105JX2GZ00V012.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/JP10002303105L92GI00T00V.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/JP11002303105H82I100X00V.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/JP12002303105LO29704E040.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/JP13002303105IN2HG00R01G.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/JP14002303105I22IF00S00H.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/JP15002303105ET2K501Z040.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/JP16002303105LL2HM00M00J.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/JP17002303105HC2IZ01H015.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/JP18002303105FI2JI01A00W.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/JP19002303105J02H800S015.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/JP20002303105M22GM00V00Y.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/JP21002303105JS2FO01501M.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/JP22002303105MO2DO01201I.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/JP23002303105JN2HX00X019.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/JP24002303105MG2EY014010.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/JP25002303105GE2JS00Y016.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/JP26002303105KK2GJ00X01G.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/JP27002303105EL2I701O02D.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/JP28002303105JG2IA00F00Q.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/JP29002303105KP2F101I01R.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/JP30002303105GH2J000W014.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/JP31002303105I02HV00Q00U.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/JP32002303105BC2N905L02Z.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/JP33002303105J42I300G00L.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/JP34002303105FQ2J400K00L.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/JP35002303105LG2H400R00F.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/JP36002303105JL2HL00G00P.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/JP37002303105GV2GX01D01R.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/JP38002303105KO2HM018010.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/JP39002303105LU2GG00M00R.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/JP40002303105I92IM00U00S.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/JP41002303105JN2HF0BM0BB.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/JP42002303105HX2HI00V00L.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/JP43002303105K82GD00M00S.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/JP44002303105J12IL00X00W.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/JP45002303105LQ2EH00Y01I.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/JP46002303105G72I201C016.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/JP47002303105L42HD00M00N.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/KH00002303104YG2WD03D03G.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/KR00002303105CC2F905304W.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/LU000023031039E24Z00I00Q.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/MX01002303101CQ2R600P00M.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/MX020023031012Y2JU03K03I.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/MX030023031014L2NB04103M.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/MX04002303101JB2SA025022.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/MX05002303101I92U702F02B.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/MX060023031018T2KJ03O04J.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/MX07002303101C12LY02N03U.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/MX08002303101572T607600U.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/MX090023031019Z2O4031036.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/MX10002303101D82RM01K01B.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/MX11002303101D62TL02O01R.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/MX12002303101EN2RW017019.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/MX13002303101AY2QZ02O02M.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/MX14002303101EY2T500A00D.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/MX15002303101C62SL02D01P.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/MX16002303101EV2TG00K00J.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/MX17002303101AB2QR01X01Q.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/MX18002303101DS2NG01S03A.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/MX19002303101FG2TQ030021.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/MX20002303101F52SA01I021.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/MX21002303101E62RQ010015.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/MX22002303101LB2RR01O02J.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/MX23002303101D32PS02K02B.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/MX240023031018L2NZ02L038.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/MX25002303101512K004804J.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/MX26002303101E52SN01B01C.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/MX27002303101I92TR02100Y.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/MX28002303101EG2NJ01X03V.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/MX29002303101FD2T100P00G.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/MX30002303101FE2R603803M.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/MX31002303101KM2RR01U01F.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/MX32002303101BS2PC02C02U.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/MY00002303104WA30Z0D004A.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/NL010023031039N21W00M00N.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/NL020023031038Z22A00M00M.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/NL030023031038T21J01100V.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/NL040023031038X22L01600V.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/NL050023031039N21H00P00U.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/NL060023031039A23D00G013.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/NL070023031038E23B01800O.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/NL080023031038L21V00L015.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/NL090023031039F22900U00T.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/NL100023031038S22U00K00H.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/NL110023031037V23D00M00M.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/NL120023031038522S00T00R.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/PE00002303101NE35Q0B20D6.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/PH000023031054O2RU09F0B6.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/PL01002303103F423C01X01R.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/PL02002303103GN21A01N01K.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/PL03002303103H622Q01O01M.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/PL04002303103JF22U01M024.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/PL05002303103EY21Z01701U.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/PL06002303103HT24N01I01C.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/PL07002303103HX21L02H02L.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/PL08002303103GG23Y015019.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/PL09002303103J424C01K01U.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/PL10002303103JE20L01J02B.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/PL11002303103GB20401W01I.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/PL12002303103H524201901Q.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/PL13002303103I723T01F017.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/PL14002303103HU20J02D01H.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/PL15002303103FQ21E02502P.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/PL16002303103EO20F01U024.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/PT00002303102LS2CB0G3083.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/RO00002303103IK26U06D048.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/RU08002303103T11YT00R011.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/RU09002303103RZ1XQ038033.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/RU14002303103SG20401Y023.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/RU16002303103TY1XW03001Z.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/RU41002303103MH1SC05V03Q.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/RU660023031045V1YF03Z04S.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/RU690023031045X1RI05P07B.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/RU810023031040220B02Y033.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/RU82002303103WM22A05B034.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/SE01002303103EU1Y901700X.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/SE02002303103DF1R302X037.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/SE03002303103EW1QZ02C02W.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/SE04002303103GX1VS01C02A.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/SE05002303103CY1WZ01H01J.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/SE06002303103DC1N0037052.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/SE07002303103E11WA01N01L.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/SE08002303103FG1WC01F02N.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/SE09002303103E61XE01M013.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/SE10002303103FH1GL05L06T.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/SE11002303103ES1TX00Z01V.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/SE12002303103EW1VA02001N.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/SE13002303103DE1Y701P01N.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/SE14002303103FM1UN01M01G.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/SE15002303103GN1TO01S02B.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/SE16002303103GB1SU01M021.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/SE17002303103D51SP01S030.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/SE18002303103ET1L404Y04V.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/SE19002303103F31OM03202R.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/SE20002303103FI1TT01001A.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/SE21002303103CG1UZ02O02L.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/SG00002303104Z834T00O009.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/TH00002303104V62SJ05D09P.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/TW000023031058F2OB032042.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/UA01002303103OH24X02301R.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/UA02002303103P122R01X023.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/UA03002303103LI26F01P00Y.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/UA04002303103Q428Q02V01V.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/UA05002303103QL25X02J01P.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/UA06002303103SV25W01M02G.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/UA07002303103KN25L01D01S.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/UA08002303103RS24P02301X.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/UA09002303103PG27G02R01R.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/UA10002303103MA24K015024.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/UA11002303103OV24L00E00D.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/UA12002303103O923L01V02E.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/UA13002303103OK25W02N01G.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/UA14002303103TO25201J028.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/UA15002303103K224I01T01X.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/UA16002303103OU26V01X01S.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/UA17002303103NL26U01Z02Z.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/UA18002303103Q124L02701U.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/UA19002303103LM23701P01Z.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/UA20002303103QO29W00K00O.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/UA21002303103QL22R01R02C.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/UA22002303103LE24W01401R.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/UA23002303103N225901P01T.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/UA24002303103KO23601M01Q.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/UA25002303103JR26101L016.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/UA26002303103RC26Y02001W.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/UA27002303103MY23G01N025.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/UK100023031030L1ZG01Z01S.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/UK11002303102WD1SM09J07V.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/UK120023031031V21B02802U.map
# factory_data/00D6-5BD8/iGPSPORT/Maps/VN00002303104YB2QK07X0AJ.map

# %%
tags = {}
for f in files:
    header = parseHeader(f)

    for tag in header.wayTags:
        if not tag in tags.keys():
            tags[tag] = 1
        else:
            tags[tag] += 1

    # if b'natural=coastline' in header.wayTags:
    #     pprint.pp(f.name)
    #     pprint.pp(vars(header))
        
    pf = parseFilename(f.name)
    data.append({"file": f, "header": header, "parsedFilename": pf, "Name": f.name})
    
pprint.pp(tags)
# Out:
# {b'highway=cycleway': 423,
#  b'highway=footway': 432,
#  b'highway=living_street': 395,
#  b'highway=path': 432,
#  b'highway=pedestrian': 431,
#  b'highway=primary': 430,
#  b'highway=primary_link': 424,
#  b'highway=residential': 432,
#  b'highway=road': 293,
#  b'highway=secondary': 432,
#  b'highway=secondary_link': 423,
#  b'highway=service': 432,
#  b'highway=tertiary': 432,
#  b'highway=tertiary_link': 426,
#  b'highway=track': 432,
#  b'highway=trunk': 421,
#  b'highway=trunk_link': 421,
#  b'highway=unclassified': 432,
#  b'natural=coastline': 227,
#  b'natural=water': 432}

# %%
names = [d["Name"] for d in data]
minLat = [d["header"].minLat for d in data]
minLon = [d["header"].minLon for d in data]
maxLat = [d["header"].maxLat for d in data]
maxLon = [d["header"].maxLon for d in data]

f1 = [d["parsedFilename"].field1 for d in data]
f2 = [d["parsedFilename"].field2 for d in data]
f3 = [d["parsedFilename"].z1 for d in data]
f4 = [d["parsedFilename"].z2 for d in data]

df = pd.DataFrame(
    {
        "name": names,
        "minLat": minLat,
        "minLon": minLon,
        "maxLat": maxLat,
        "maxLon": maxLon,
        "f1": f1,
        "f2": f2,
        "f3": f3,
        "f4": f4,
    }
)
df["minLat"] = df["minLat"]
df["minLon"] = df["minLon"]
df["maxLat"] = df["maxLat"]
df["maxLon"] = df["maxLon"]

# %%
traces = []

maxLon = -360
minLon = 360
maxLat = -360
minLat = 360

for index, row in df.iterrows():

    maxLon = row["maxLon"] if row["maxLon"] > maxLon else maxLon
    minLon = row["minLon"] if row["minLon"] < minLon else minLon
    maxLat = row["maxLat"] if row["maxLat"] > maxLat else maxLat
    minLat = row["minLat"] if row["minLat"] < minLat else minLat

    traces.append(
        go.Scattermap(
            mode="lines",
            fill="toself",
            name=row["name"],
            lon=[row["maxLon"], row["minLon"], row["minLon"], row["maxLon"]],
            lat=[row["maxLat"], row["maxLat"], row["minLat"], row["minLat"]],
            text=[row["name"], row["name"], row["name"], row["name"]],
        )
    )


traces.append(
    go.Scattermap(
        mode="lines",
        fill="toself",
        name="all",
        lon=[maxLon, minLon, minLon, maxLon],
        lat=[maxLat, maxLat, minLat, minLat],
        text=["all", "all", "all", "all"],
    )
)


fig = go.Figure(data=traces)

fig.update_layout(
    map={"style": "carto-darkmatter"},
    margin={"l": 0, "r": 0, "b": 0, "t": 0},
)

fig.write_html("docs/BoundingBoxes.html")
